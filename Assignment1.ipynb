# %% [markdown]
# <a href="https://colab.research.google.com/github/RohanDoshi21/PICT-TE-SEM6-DSBDAL/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import *

# %%
df=read_csv('https://raw.githubusercontent.com/RohanDoshi21/PICT-TE-SEM6-DSBDAL/main/Asgn1_melb_data.csv')
df # To check if the data frame is imported correctly
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
# Tells us about the dataset like mean, deviation, max etc
df.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %%
# Tells us if any value in the dataset is null
df.isna().sum()
# Out:
# Unnamed: 0           0
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          3469
# Bathroom          3471
# Car               3576
# Landsize          4793
# BuildingArea     10634
# YearBuilt         9438
# CouncilArea       6163
# Lattitude         3332
# Longtitude        3332
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
# Remove all rows with null values
# df.dropna()

# any missing value is filled based on the corresponding value in the previous row
df = df.ffill()
# Fills based on backward values
df = df.bfill()
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
# Shows no of rows and column
df.shape
# Out:
# (18396, 22)

# %%
# shows all the datatypes
df.dtypes
# Out:
# Unnamed: 0         int64
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df=df.astype({'YearBuilt': int})
df.dtypes
# Out:
# Unnamed: 0         int64
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt          int64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
# Normalization -> Means Feature Scaling
# Now if a column has greater scale (val) as compared to other column it will have significant impact than the others
df['Price'] = (df['Price'] - df['Price'].min())/(df['Price'].max()-df['Price'].min())
# How the Price column will vary from 0 to 1
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type     Price  \
# 0               1    Abbotsford      85 Turner St      2    h  0.156478
# 1               2    Abbotsford   25 Bloomburg St      2    h  0.106562
# 2               4    Abbotsford      5 Charles St      3    h  0.154795
# 3               5    Abbotsford  40 Federation La      3    h  0.085810
# 4               6    Abbotsford       55a Park St      4    h  0.169938
# ...           ...           ...               ...    ...  ...       ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t  0.060292
# 18392       23541  Williamstown      96 Verdon St      4    h  0.270892
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  0.113853
# 18394       23545    Yarraville        6 Agnes St      4    h  0.134605
# 18395       23546    Yarraville     33 Freeman St      4    h  0.108245
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
df['Type'].unique()
# Out:
# array(['h', 't', 'u'], dtype=object)

# %%
# Catagoral values to numberical form
# from sklearn.preprocessing import OneHotEncoder
# enc = OneHotEncoder()

# dt = df['Type'].to_numpy().reshape(-1,1)
# arr = enc.fit_transform(dt).toarray()
# # To Add to DataFrame as column
# arr = DataFrame(arr)
# df = df.join(arr)
# df

# %%
# # Changing column name generated by OneHotEncoder
# df.rename(columns={0: "h", 1 : "t", 2 : "u"}, inplace=True)
# # Droping values in the values

# Simpler way to use OneHotEncoder
# This is a simpler way to use on hot encoder
dfType = get_dummies(df['Type'])
dfType
# Out:
#        h  t  u
# 0      1  0  0
# 1      1  0  0
# 2      1  0  0
# 3      1  0  0
# 4      1  0  0
# ...   .. .. ..
# 18391  0  1  0
# 18392  1  0  0
# 18393  1  0  0
# 18394  1  0  0
# 18395  1  0  0
#
# [18396 rows x 3 columns]

# %%
df = df.join(dfType)

# %%
df.drop(['Type'], axis=1, inplace=True)
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms     Price Method  \
# 0               1    Abbotsford      85 Turner St      2  0.156478      S
# 1               2    Abbotsford   25 Bloomburg St      2  0.106562      S
# 2               4    Abbotsford      5 Charles St      3  0.154795     SP
# 3               5    Abbotsford  40 Federation La      3  0.085810     PI
# 4               6    Abbotsford       55a Park St      4  0.169938     VB
# ...           ...           ...               ...    ...       ...    ...
# 18391       23540  Williamstown   8/2 Thompson St      2  0.060292     SP
# 18392       23541  Williamstown      96 Verdon St      4  0.270892     PI
# 18393       23544     Yallambie      17 Amaroo Wy      4  0.113853      S
# 18394       23545    Yarraville        6 Agnes St      4  0.134605     SP
# 18395       23546    Yarraville     33 Freeman St      4  0.108245     VB
#
#           SellerG        Date  Distance  Postcode  ...  BuildingArea  \
# ...

# %%
# Transform 
# df['Type'] = df['Type'].replace({'h': 0, 't': 1, 'u' : 2})\
# This is not a correct way of doing it
